# %%
import mlflow.spark

# %%
import os
import warnings
import sys
import mlflow
import pandas as pd
import numpy as np
from sklearn.metrics import mean_squared_error, mean_absolute_error, r2_score
from sklearn.model_selection import train_test_split
from sklearn.linear_model import ElasticNet

# %%
import logging
import json
import shutil
import datetime
from pyspark.sql import SparkSession
from pyspark.ml import Pipeline
from pyspark.ml.classification import LogisticRegression
from pyspark.ml.feature import HashingTF, Tokenizer
import cml.data_v1 as cmldata

# %%
#Edit your connection name here:
CONNECTION_NAME = "go01-aw-dl"

conn = cmldata.get_connection(CONNECTION_NAME)
spark = conn.get_spark_session()
# Out:
# Spark Application Id:spark-c9ab2527cc834e77b7fbcd33ade19c00

# %%
training_df = spark.createDataFrame(
[
    ("0", "a b c d e spark", 1.0),
    ("1", "b d", 0.0),
    ("2", "spark f g h", 1.0),
    ("3", "hadoop mapreduce", 0.0),
],
["id", "text", "label"],
)

# %%
def exp1(df):

    mlflow.set_experiment("sparkml-experiment-new")

    ##EXPERIMENT 1

    df.writeTo("spark_catalog.default.training").using("iceberg").createOrReplace()
    spark.sql("SELECT * FROM spark_catalog.default.training").show()

    ### SHOW TABLE HISTORY AND SNAPSHOTS
    spark.read.format("iceberg").load("spark_catalog.default.training.history").show(20, False)
    spark.read.format("iceberg").load("spark_catalog.default.training.snapshots").show(20, False)

    snapshot_id = spark.read.format("iceberg").load("spark_catalog.default.training.snapshots").select("snapshot_id").tail(1)[0][0]
    committed_at = spark.read.format("iceberg").load("spark_catalog.default.training.snapshots").select("committed_at").tail(1)[0][0].strftime('%m/%d/%Y')
    parent_id = spark.read.format("iceberg").load("spark_catalog.default.training.snapshots").select("parent_id").tail(1)[0][0]
    
    tags = {
      "iceberg_snapshot_id": snapshot_id,
      "iceberg_snapshot_committed_at": committed_at,
      "iceberg_parent_id": parent_id,
      "row_count": training_df.count()
    }
    
    ### MLFLOW EXPERIMENT RUN
    with mlflow.start_run() as run:

        maxIter=8
        regParam=0.01

        tokenizer = Tokenizer(inputCol="text", outputCol="words")
        hashingTF = HashingTF(inputCol=tokenizer.getOutputCol(), outputCol="features")
        lr = LogisticRegression(maxIter=maxIter, regParam=regParam)
        pipeline = Pipeline(stages=[tokenizer, hashingTF, lr])
        model = pipeline.fit(training_df)

        mlflow.log_param("maxIter", maxIter)
        mlflow.log_param("regParam", regParam)

        #storage_path = "s3://go01-demo/pdefusco/tests/sparkmodels"
        mlflow.spark.log_model(model, artifact_path="pipe_artifacts", dfs_tmpdir="/home/cdsw/models-tests") #, 
        #mlflow.spark.save_model(model, path="pipe_artifacts")
        #model.write().overwrite().save("/home/cdsw/model/pdefusco/pipeline") #"s3a://go01-demo"

        #prediction = model.transform(test)
        mlflow.set_tags(tags)

    mlflow.end_run()
    
    experiment_id = mlflow.get_experiment_by_name("sparkml-experiment-new").experiment_id
    runs_df = mlflow.search_runs(experiment_id, run_view_type=1)
    
    return runs_df

# %%
#!hdfs dfs -ls hdfs://ns1

# %%
exp1(training_df)
# Out:
# +---+----------------+-----+
# | id|            text|label|
# +---+----------------+-----+
# |  0| a b c d e spark|  1.0|
# |  1|             b d|  0.0|
# |  2|     spark f g h|  1.0|
# |  3|hadoop mapreduce|  0.0|
# +---+----------------+-----+
#
# +-----------------------+-------------------+---------+-------------------+
# |made_current_at        |snapshot_id        |parent_id|is_current_ancestor|
# +-----------------------+-------------------+---------+-------------------+
# |2024-09-27 22:05:04.216|6283834449287593171|null     |true               |
# +-----------------------+-------------------+---------+-------------------+
#
# +-----------------------+-------------------+-------------------+---------+----------------------------------------------------------------------------------------------------------------------------------------------------------------------+------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+
# |committed_at           |snapshot_id        |parent_id          |operation|manifest_list                                                                                                                                                         |summary                                                                                                                                                                                                                                                                                                                 |
# +-----------------------+-------------------+-------------------+---------+----------------------------------------------------------------------------------------------------------------------------------------------------------------------+------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+
# |2023-03-10 20:22:22.662|2693814795059767550|null               |append   |s3a://go01-demo/warehouse/tablespace/external/hive/cdh_test/user/hive/warehouse/training/metadata/snap-2693814795059767550-1-26bf3275-0195-45d6-a92d-c80f445cc568.avro|{spark.app.id -> local-1678478239199, added-data-files -> 2, added-records -> 4, added-files-size -> 1822, changed-partition-count -> 1, total-records -> 4, total-files-size -> 1822, total-data-files -> 2, total-delete-files -> 0, total-position-deletes -> 0, total-equality-deletes -> 0}                        |
# |2023-03-10 20:23:04.731|2957939241357099335|2693814795059767550|append   |s3a://go01-demo/warehouse/tablespace/external/hive/cdh_test/user/hive/warehouse/training/metadata/snap-2957939241357099335-1-4665298e-07c6-4164-b65a-6538058b2e18.avro|{spark.app.id -> local-1678478239199, added-data-files -> 1, added-records -> 4, added-files-size -> 996, changed-partition-count -> 1, total-records -> 8, total-files-size -> 2818, total-data-files -> 3, total-delete-files -> 0, total-position-deletes -> 0, total-equality-deletes -> 0}                         |
# |2023-03-31 14:51:03.217|3843157946227379170|null               |append   |s3a://go01-demo/warehouse/tablespace/external/hive/cdh_test/user/hive/warehouse/training/metadata/snap-3843157946227379170-1-fd02f7c5-abf3-4b89-8ee2-dc76d16746c9.avro|{spark.app.id -> spark-application-1680274218303, added-data-files -> 2, added-records -> 4, added-files-size -> 1822, changed-partition-count -> 1, total-records -> 4, total-files-size -> 1822, total-data-files -> 2, total-delete-files -> 0, total-position-deletes -> 0, total-equality-deletes -> 0}            |
# |2023-03-31 14:51:13.942|5852654135945392377|3843157946227379170|append   |s3a://go01-demo/warehouse/tablespace/external/hive/cdh_test/user/hive/warehouse/training/metadata/snap-5852654135945392377-1-dc55f98f-017c-40a0-9d13-81831f2e2780.avro|{spark.app.id -> spark-application-1680274218303, added-data-files -> 1, added-records -> 4, added-files-size -> 996, changed-partition-count -> 1, total-records -> 8, total-files-size -> 2818, total-data-files -> 3, total-delete-files -> 0, total-position-deletes -> 0, total-equality-deletes -> 0}             |
# |2023-11-05 19:48:13.242|426957395241265414 |null               |append   |s3a://go01-demo/warehouse/tablespace/external/hive/cdh_test/user/hive/warehouse/training/metadata/snap-426957395241265414-1-34ed070c-e000-49ae-aa29-d11b16ed6986.avro |{spark.app.id -> spark-application-1699213645495, added-data-files -> 2, added-records -> 4, added-files-size -> 1822, changed-partition-count -> 1, total-records -> 4, total-files-size -> 1822, total-data-files -> 2, total-delete-files -> 0, total-position-deletes -> 0, total-equality-deletes -> 0}            |
# |2023-11-05 19:51:28.961|4225021400360977669|426957395241265414 |append   |s3a://go01-demo/warehouse/tablespace/external/hive/cdh_test/user/hive/warehouse/training/metadata/snap-4225021400360977669-1-7df2b18c-960f-42ea-b8bd-e5587bf1bb05.avro|{spark.app.id -> spark-application-1699213645495, added-data-files -> 1, added-records -> 4, added-files-size -> 996, changed-partition-count -> 1, total-records -> 8, total-files-size -> 2818, total-data-files -> 3, total-delete-files -> 0, total-position-deletes -> 0, total-equality-deletes -> 0}             |
# |2023-11-06 17:08:18.36 |1283984402985061615|null               |append   |s3a://go01-demo/warehouse/tablespace/external/hive/cdh_test/user/hive/warehouse/training/metadata/snap-1283984402985061615-1-3a51f11c-4632-4362-8751-97ed354a9f13.avro|{spark.app.id -> spark-application-1699290449499, added-data-files -> 2, added-records -> 4, added-files-size -> 1822, changed-partition-count -> 1, total-records -> 4, total-files-size -> 1822, total-data-files -> 2, total-delete-files -> 0, total-position-deletes -> 0, total-equality-deletes -> 0}            |
# |2023-11-06 17:08:41.886|985373206992651716 |1283984402985061615|append   |s3a://go01-demo/warehouse/tablespace/external/hive/cdh_test/user/hive/warehouse/training/metadata/snap-985373206992651716-1-6438e950-ab93-4330-8755-5b0377abfdf8.avro |{spark.app.id -> spark-application-1699290449499, added-data-files -> 1, added-records -> 4, added-files-size -> 996, changed-partition-count -> 1, total-records -> 8, total-files-size -> 2818, total-data-files -> 3, total-delete-files -> 0, total-position-deletes -> 0, total-equality-deletes -> 0}             |
# |2023-11-06 17:15:12.597|4748800489323277205|null               |append   |s3a://go01-demo/warehouse/tablespace/external/hive/cdh_test/user/hive/warehouse/training/metadata/snap-4748800489323277205-1-d5c538f4-9692-4210-b493-553dc66a98ab.avro|{spark.app.id -> spark-application-1699290449499, added-data-files -> 2, added-records -> 4, added-files-size -> 1822, changed-partition-count -> 1, total-records -> 4, total-files-size -> 1822, total-data-files -> 2, total-delete-files -> 0, total-position-deletes -> 0, total-equality-deletes -> 0}            |
# |2023-11-06 17:17:23.056|7803587387117571530|4748800489323277205|append   |s3a://go01-demo/warehouse/tablespace/external/hive/cdh_test/user/hive/warehouse/training/metadata/snap-7803587387117571530-1-6d84cab1-1af5-416d-843c-79de4567c56e.avro|{spark.app.id -> spark-application-1699290449499, added-data-files -> 1, added-records -> 4, added-files-size -> 996, changed-partition-count -> 1, total-records -> 8, total-files-size -> 2818, total-data-files -> 3, total-delete-files -> 0, total-position-deletes -> 0, total-equality-deletes -> 0}             |
# |2023-11-06 17:37:58.667|7226728052987263076|null               |append   |s3a://go01-demo/warehouse/tablespace/external/hive/cdh_test/user/hive/warehouse/training/metadata/snap-7226728052987263076-1-5a434fa5-5be1-452a-8892-5ab96d62b6e2.avro|{spark.app.id -> spark-application-1699290449499, added-data-files -> 2, added-records -> 4, added-files-size -> 1822, changed-partition-count -> 1, total-records -> 4, total-files-size -> 1822, total-data-files -> 2, total-delete-files -> 0, total-position-deletes -> 0, total-equality-deletes -> 0}            |
# |2023-11-06 17:38:44.717|4665871762421835805|7226728052987263076|append   |s3a://go01-demo/warehouse/tablespace/external/hive/cdh_test/user/hive/warehouse/training/metadata/snap-4665871762421835805-1-e3e55e42-a674-4318-b8ca-524ed12f4d00.avro|{spark.app.id -> spark-application-1699290449499, added-data-files -> 1, added-records -> 4, added-files-size -> 996, changed-partition-count -> 1, total-records -> 8, total-files-size -> 2818, total-data-files -> 3, total-delete-files -> 0, total-position-deletes -> 0, total-equality-deletes -> 0}             |
# |2023-11-06 22:41:16.592|1869813012622947967|null               |append   |s3a://go01-demo/warehouse/tablespace/external/hive/cdh_test/user/hive/warehouse/training/metadata/snap-1869813012622947967-1-5d6d3a43-29cc-4f92-8491-dadd9a522f1a.avro|{spark.app.id -> spark-application-1699309919240, added-data-files -> 8, added-records -> 10000, added-files-size -> 240773, changed-partition-count -> 1, total-records -> 10000, total-files-size -> 240773, total-data-files -> 8, total-delete-files -> 0, total-position-deletes -> 0, total-equality-deletes -> 0}|
# |2023-11-06 22:42:28.741|1686784375792724371|1869813012622947967|append   |s3a://go01-demo/warehouse/tablespace/external/hive/cdh_test/user/hive/warehouse/training/metadata/snap-1686784375792724371-1-c89aaa60-bb4e-478a-9948-3cbe3c827aad.avro|{spark.app.id -> spark-application-1699309919240, added-data-files -> 1, added-records -> 10000, added-files-size -> 224104, changed-partition-count -> 1, total-records -> 20000, total-files-size -> 464877, total-data-files -> 9, total-delete-files -> 0, total-position-deletes -> 0, total-equality-deletes -> 0}|
# |2023-11-07 00:46:35.819|9156887932120339490|null               |append   |s3a://go01-demo/warehouse/tablespace/external/hive/cdh_test/user/hive/warehouse/training/metadata/snap-9156887932120339490-1-c8d4ad99-f994-4d2a-a51b-7be07590372d.avro|{spark.app.id -> spark-application-1699317908319, added-data-files -> 8, added-records -> 10000, added-files-size -> 240037, changed-partition-count -> 1, total-records -> 10000, total-files-size -> 240037, total-data-files -> 8, total-delete-files -> 0, total-position-deletes -> 0, total-equality-deletes -> 0}|
# |2023-11-07 00:47:23.597|1150142163802369700|9156887932120339490|append   |s3a://go01-demo/warehouse/tablespace/external/hive/cdh_test/user/hive/warehouse/training/metadata/snap-1150142163802369700-1-9467ac12-c46f-4a01-bb59-40da558a5a5e.avro|{spark.app.id -> spark-application-1699317908319, added-data-files -> 1, added-records -> 10000, added-files-size -> 223347, changed-partition-count -> 1, total-records -> 20000, total-files-size -> 463384, total-data-files -> 9, total-delete-files -> 0, total-position-deletes -> 0, total-equality-deletes -> 0}|
# |2023-11-07 00:53:49.741|4733784340876419169|null               |append   |s3a://go01-demo/warehouse/tablespace/external/hive/cdh_test/user/hive/warehouse/training/metadata/snap-4733784340876419169-1-a9e0e4e1-1683-4d6c-b6b7-46d1555ff88c.avro|{spark.app.id -> spark-application-1699318383253, added-data-files -> 8, added-records -> 10000, added-files-size -> 379295, changed-partition-count -> 1, total-records -> 10000, total-files-size -> 379295, total-data-files -> 8, total-delete-files -> 0, total-position-deletes -> 0, total-equality-deletes -> 0}|
# |2023-11-07 00:54:40.707|2504239286908645214|4733784340876419169|append   |s3a://go01-demo/warehouse/tablespace/external/hive/cdh_test/user/hive/warehouse/training/metadata/snap-2504239286908645214-1-47df449d-fd5a-47b6-9af2-6523ce26b87d.avro|{spark.app.id -> spark-application-1699318383253, added-data-files -> 1, added-records -> 10000, added-files-size -> 374010, changed-partition-count -> 1, total-records -> 20000, total-files-size -> 753305, total-data-files -> 9, total-delete-files -> 0, total-position-deletes -> 0, total-equality-deletes -> 0}|
# |2023-12-06 00:26:33.056|1374289690540954212|null               |append   |s3a://go01-demo/warehouse/tablespace/external/hive/cdh_test/user/hive/warehouse/training/metadata/snap-1374289690540954212-1-8b7e448c-43fd-49f2-a221-772fb00b98e8.avro|{spark.app.id -> spark-application-1701822324257, added-data-files -> 8, added-records -> 10000, added-files-size -> 379404, changed-partition-count -> 1, total-records -> 10000, total-files-size -> 379404, total-data-files -> 8, total-delete-files -> 0, total-position-deletes -> 0, total-equality-deletes -> 0}|
# |2023-12-06 00:27:24.389|6833554684804309829|1374289690540954212|append   |s3a://go01-demo/warehouse/tablespace/external/hive/cdh_test/user/hive/warehouse/training/metadata/snap-6833554684804309829-1-9c06386c-bdae-4dc5-afad-8d0bd03bfc39.avro|{spark.app.id -> spark-application-1701822324257, added-data-files -> 1, added-records -> 10000, added-files-size -> 373985, changed-partition-count -> 1, total-records -> 20000, total-files-size -> 753389, total-data-files -> 9, total-delete-files -> 0, total-position-deletes -> 0, total-equality-deletes -> 0}|
# +-----------------------+-------------------+-------------------+---------+----------------------------------------------------------------------------------------------------------------------------------------------------------------------+------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+
# only showing top 20 rows
# 2024/09/27 22:05:33 WARNING mlflow.utils.environment: Encountered an unexpected error while inferring pip requirements (model URI: /tmp/tmpe_gdsvmj/model, flavor: spark), fall back to return ['pyspark==3.3.0', 'pandas<2']. Set logging level to DEBUG to see the full traceback.
# 2024/09/27 22:05:33 WARNING mlflow.utils.requirements_utils: Detected one or more mismatches between the model's dependencies and the current Python environment:
#  - pandas (current: 2.1.4, required: pandas<2)
# To fix the mismatches, call `mlflow.pyfunc.get_model_dependencies(model_uri)` to fetch the model's environment and install dependencies using the resulting environment file.
#                 run_id        experiment_id                   status  \
# 0  ks3e-rcak-poz8-uwku  20y8-rgzd-3tpf-i665  EXPERIMENT_RUN_FINISHED
# 1  s21y-bleu-ym1a-2b1w  20y8-rgzd-3tpf-i665  EXPERIMENT_RUN_FINISHED
#
#                                         artifact_uri  \
# 0  /home/cdsw/.experiments/20y8-rgzd-3tpf-i665/ks...
# 1  /home/cdsw/.experiments/20y8-rgzd-3tpf-i665/s2...
#
#                            start_time                            end_time  \
# 0 2024-09-27 21:54:47.358342144+00:00 2024-09-27 21:55:19.035000064+00:00
# 1 2024-09-27 22:05:12.874052864+00:00 2024-09-27 22:05:35.179000064+00:00
#
#   params.maxIter params.regParam tags.iceberg_parent_id  \
# 0              8            0.01                   None
# 1              8            0.01                   None
#
#                        tags.mlflow.log-model.history tags.row_count  \
# 0  [{"run_id": "ks3e-rcak-poz8-uwku", "artifact_p...              4
# 1  [{"run_id": "s21y-bleu-ym1a-2b1w", "artifact_p...              4
#
#   tags.mlflow.user     tags.engineID tags.mlflow.source.type  \
# 0      pauldefusco  qrgk2h3tnwrrm71d                   LOCAL
# 1      pauldefusco  qrgk2h3tnwrrm71d                   LOCAL
#
#   tags.iceberg_snapshot_id tags.iceberg_snapshot_committed_at  \
# 0      8782431286665847158                         09/27/2024
# 1      6283834449287593171                         09/27/2024
#
#                              tags.mlflow.source.name  \
# 0  /usr/local/lib/python3.10/site-packages/ipyker...
# 1  /usr/local/lib/python3.10/site-packages/ipyker...
#
#               tags.mlflow.source.git.commit
# 0  06b7bed0031ad636f6b3ade4189ea15b164906f3
# 1  06b7bed0031ad636f6b3ade4189ea15b164906f3

# %%
mlflow.get_artifact_uri()
# Out:
# '/home/cdsw/.experiments/43o0-djev-9a4c-t44t/onjl-k0ff-tcf6-x5nm/artifacts'

# %%
predictions.show()
# Out:
# [Stage 98:>                                                         (0 + 1) / 1]
# +---+----------------+--------------------+--------------------+--------------------+--------------------+----------+
# | id|            text|               words|            features|       rawPrediction|         probability|prediction|
# +---+----------------+--------------------+--------------------+--------------------+--------------------+----------+
# |  0| a b c d e spark|[a, b, c, d, e, s...|(262144,[74920,89...|[-4.0215432342565...|[0.01760962323702...|       1.0|
# |  1|             b d|              [b, d]|(262144,[89530,14...|[3.72362151547898...|[0.97642293742550...|       0.0|
# |  2|     spark f g h|    [spark, f, g, h]|(262144,[36803,17...|[-4.1749669283492...|[0.01514286794945...|       1.0|
# |  3|hadoop mapreduce| [hadoop, mapreduce]|(262144,[132966,1...|[4.67558415487772...|[0.99076598259580...|       0.0|
# +---+----------------+--------------------+--------------------+--------------------+--------------------+----------+

# %%
from pyspark.ml import PipelineModel 
# Path where the pipeline model was saved 
path = "path_to_saved_pipeline_model" 
# Load the fitted pipeline model loaded_pipeline_model = PipelineModel.load(path) # Now you can use the model to make predictions predictions = loaded_pipeline_model.transform(test_data)

# %%
test_df = spark.createDataFrame(
[
    ("0", "a b c d e spark"),
    ("1", "b d"),
    ("2", "spark f g h"),
    ("3", "hadoop mapreduce"),
],
["id", "text"],
)

# %%
import mlflow

logged_model = '/home/cdsw/.experiments/to9f-oq8b-qch6-u3ex/3oxt-tjek-73lg-danq/artifacts/artifacts'

# Load model as a Spark UDF.
loaded_model = mlflow.pyfunc.spark_udf(spark, model_uri=logged_model)

# Predict on a Spark DataFrame.
test_df.withColumn('predictions', loaded_model(*column_names)).collect()
# Out:
# 2024/09/27 17:43:58 WARNING mlflow.utils.requirements_utils: Detected one or more mismatches between the model's dependencies and the current Python environment:
#  - pandas (current: 2.1.4, required: pandas<2)
# To fix the mismatches, call `mlflow.pyfunc.get_model_dependencies(model_uri)` to fetch the model's environment and install dependencies using the resulting environment file.
# 2024/09/27 17:43:58 WARNING mlflow.pyfunc: Calling `spark_udf()` with `env_manager="local"` does not recreate the same environment that was used during training, which may lead to errors or inaccurate predictions. We recommend specifying `env_manager="conda"`, which automatically recreates the environment that was used to train the model and performs inference in the recreated environment.
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[14], line 6
#       3 logged_model = '/home/cdsw/.experiments/to9f-oq8b-qch6-u3ex/3oxt-tjek-73lg-danq/artifacts/artifacts'
#       5 # Load model as a Spark UDF.
# ----> 6 loaded_model = mlflow.pyfunc.spark_udf(spark, model_uri=logged_model)
#       8 # Predict on a Spark DataFrame.
#       9 test_df.withColumn('predictions', loaded_model(*column_names)).collect()
#
# File /opt/cmladdons/python/site-packages/mlflow/pyfunc/__init__.py:1421, in spark_udf(spark, model_uri, result_type, env_manager, params, extra_env)
#    1411     if not sys.platform.startswith("linux"):
#    1412         # TODO: support killing mlflow server launched in UDF task when spark job canceled
#    1413         #  for non-linux system.
#    1414         #  https://stackoverflow.com/questions/53208/how-do-i-automatically-destroy-child-processes-in-windows
#    1415         _logger.warning(
#    1416             "In order to run inference code in restored python environment, PySpark UDF "
#    1417             "processes spawn MLflow Model servers as child processes. Due to system "
#    1418             "limitations with handling SIGKILL signals, these MLflow Model server child "
#    1419             "processes cannot be cleaned up if the Spark Job is canceled."
#    1420         )
# -> 1421 pyfunc_backend = get_flavor_backend(
#    1422     local_model_path,
#    1423     env_manager=env_manager,
#    1424     install_mlflow=os.environ.get("MLFLOW_HOME") is not None,
#    1425     create_env_root_dir=True,
#    1426 )
#    1427 if not should_use_spark_to_broadcast_file:
#    1428     # Prepare restored environment in driver side if possible.
#    1429     # Note: In databricks runtime, because databricks notebook cell output cannot capture
#    (...)
#    1435     # to wait conda command fail and suddenly get all output printed (included in error
#    1436     # message).
#    1437     if env_manager != _EnvManager.LOCAL:
#
# File /opt/cmladdons/python/site-packages/mlflow/models/flavor_backend_registry.py:50, in get_flavor_backend(model_uri, **kwargs)
#      48 else:
#      49     model = None
# ---> 50 flavor_name, flavor_backend = _get_flavor_backend_for_local_model(model, **kwargs)
#      51 if flavor_backend is None:
#      52     raise Exception("No suitable flavor backend was found for the model.")
#
# File /opt/cmladdons/python/site-packages/mlflow/models/flavor_backend_registry.py:22, in _get_flavor_backend_for_local_model(model, build_docker, **kwargs)
#      20 def _get_flavor_backend_for_local_model(model=None, build_docker=True, **kwargs):
#      21     from mlflow import pyfunc
# ---> 22     from mlflow.pyfunc.backend import PyFuncBackend
#      23     from mlflow.rfunc.backend import RFuncBackend
#      25     if not model:
#
# File /opt/cmladdons/python/site-packages/mlflow/pyfunc/backend.py:15
#      13 from mlflow.exceptions import MlflowException
#      14 from mlflow.models import FlavorBackend, docker_utils
# ---> 15 from mlflow.pyfunc import (
#      16     ENV,
#      17     _extract_conda_env,
#      18     _mlflow_pyfunc_backend_predict,
#      19     mlserver,
#      20     scoring_server,
#      21 )
#      22 from mlflow.tracking.artifact_utils import _download_artifact_from_uri
#      23 from mlflow.utils import env_manager as _EnvManager
#
# File /opt/cmladdons/python/site-packages/mlflow/pyfunc/_mlflow_pyfunc_backend_predict.py:6
#       1 """
#       2 This script should be executed in a fresh python interpreter process using `subprocess`.
#       3 """
#       4 import argparse
# ----> 6 from mlflow.pyfunc.scoring_server import _predict
#       9 def parse_args():
#      10     parser = argparse.ArgumentParser()
#
# File /opt/cmladdons/python/site-packages/mlflow/pyfunc/scoring_server/__init__.py:24
#      21 import traceback
#      22 from typing import Dict, NamedTuple, Optional, Tuple
# ---> 24 import flask
#      26 from mlflow.environment_variables import MLFLOW_SCORING_SERVER_REQUEST_TIMEOUT
#      28 # NB: We need to be careful what we import form mlflow here. Scoring server is used from within
#      29 # model's conda environment. The version of mlflow doing the serving (outside) and the version of
#      30 # mlflow in the model's conda environment (inside) can differ. We should therefore keep mlflow
#      31 # dependencies to the minimum here.
#      32 # ALl of the mlflow dependencies below need to be backwards compatible.
#
# ModuleNotFoundError: No module named 'flask'

# %%
exp2(training_df)
# Out:
# +---+----------------+-----+
# | id|            text|label|
# +---+----------------+-----+
# |  0| a b c d e spark|  1.0|
# |  1|             b d|  0.0|
# |  2|     spark f g h|  1.0|
# |  3|hadoop mapreduce|  0.0|
# +---+----------------+-----+
# +---+----------------+-----+
# | id|            text|label|
# +---+----------------+-----+
# |  0| a b c d e spark|  1.0|
# |  1|             b d|  0.0|
# |  2|     spark f g h|  1.0|
# |  3|hadoop mapreduce|  0.0|
# |  0| a b c d e spark|  1.0|
# |  1|             b d|  0.0|
# |  2|     spark f g h|  1.0|
# |  3|hadoop mapreduce|  0.0|
# +---+----------------+-----+
#
# +-----------------------+-------------------+-------------------+-------------------+
# |made_current_at        |snapshot_id        |parent_id          |is_current_ancestor|
# +-----------------------+-------------------+-------------------+-------------------+
# |2023-03-29 01:09:41.31 |5150219139107687331|null               |true               |
# |2023-03-29 01:11:42.278|8171776268264279750|5150219139107687331|true               |
# +-----------------------+-------------------+-------------------+-------------------+
#
# +-----------------------+-------------------+-------------------+---------+-------------------------------------------------------------------------------------------------------------------------------------------------+------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+
# |committed_at           |snapshot_id        |parent_id          |operation|manifest_list                                                                                                                                    |summary                                                                                                                                                                                                                                                                                                     |
# +-----------------------+-------------------+-------------------+---------+-------------------------------------------------------------------------------------------------------------------------------------------------+------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+
# |2023-03-29 01:04:36.056|6707612621538684786|null               |append   |s3a://goes-se-sandbox01/warehouse/tablespace/external/hive/training/metadata/snap-6707612621538684786-1-c4dbf272-3f64-458f-bf2f-18df0abe5bc5.avro|{spark.app.id -> spark-application-1680051418888, added-data-files -> 2, added-records -> 4, added-files-size -> 1822, changed-partition-count -> 1, total-records -> 4, total-files-size -> 1822, total-data-files -> 2, total-delete-files -> 0, total-position-deletes -> 0, total-equality-deletes -> 0}|
# |2023-03-29 01:06:51.446|5645659268126732830|null               |append   |s3a://goes-se-sandbox01/warehouse/tablespace/external/hive/training/metadata/snap-5645659268126732830-1-2022b595-566d-4f8e-b198-0c7f7c96b60b.avro|{spark.app.id -> spark-application-1680051418888, added-data-files -> 2, added-records -> 4, added-files-size -> 1822, changed-partition-count -> 1, total-records -> 4, total-files-size -> 1822, total-data-files -> 2, total-delete-files -> 0, total-position-deletes -> 0, total-equality-deletes -> 0}|
# |2023-03-29 01:09:41.31 |5150219139107687331|null               |append   |s3a://goes-se-sandbox01/warehouse/tablespace/external/hive/training/metadata/snap-5150219139107687331-1-d9513182-ccce-4e6b-9a60-91442f0e5c80.avro|{spark.app.id -> spark-application-1680051418888, added-data-files -> 2, added-records -> 4, added-files-size -> 1822, changed-partition-count -> 1, total-records -> 4, total-files-size -> 1822, total-data-files -> 2, total-delete-files -> 0, total-position-deletes -> 0, total-equality-deletes -> 0}|
# |2023-03-29 01:11:42.278|8171776268264279750|5150219139107687331|append   |s3a://goes-se-sandbox01/warehouse/tablespace/external/hive/training/metadata/snap-8171776268264279750-1-045ddeac-daac-418b-a5c6-a84731d8234a.avro|{spark.app.id -> spark-application-1680051418888, added-data-files -> 1, added-records -> 4, added-files-size -> 996, changed-partition-count -> 1, total-records -> 8, total-files-size -> 2818, total-data-files -> 3, total-delete-files -> 0, total-position-deletes -> 0, total-equality-deletes -> 0} |
# +-----------------------+-------------------+-------------------+---------+-------------------------------------------------------------------------------------------------------------------------------------------------+------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+
#                 run_id        experiment_id                   status  \
# 0  kfnc-iesm-r79x-nqcp  p1y7-kv7u-fkya-ca0e   EXPERIMENT_RUN_RUNNING
# 1  vaza-u8gd-dbkd-k4ow  p1y7-kv7u-fkya-ca0e    EXPERIMENT_RUN_FAILED
# 2  55oy-jgoj-sxwp-tp7b  p1y7-kv7u-fkya-ca0e  EXPERIMENT_RUN_FINISHED
# 3  bmxd-ywal-739v-3ikq  p1y7-kv7u-fkya-ca0e  EXPERIMENT_RUN_FINISHED
#
#                                         artifact_uri  \
# 0  /home/cdsw/.experiments/p1y7-kv7u-fkya-ca0e/kf...
# 1  /home/cdsw/.experiments/p1y7-kv7u-fkya-ca0e/va...
# 2  /home/cdsw/.experiments/p1y7-kv7u-fkya-ca0e/55...
# 3  /home/cdsw/.experiments/p1y7-kv7u-fkya-ca0e/bm...
#
#                            start_time                            end_time  \
# 0 2023-03-29 01:04:44.571115008+00:00                                 NaT
# 1 2023-03-29 01:06:53.296070144+00:00 2023-03-29 01:06:56.807000064+00:00
# 2 2023-03-29 01:09:43.688317184+00:00    2023-03-29 01:09:46.864000+00:00
# 3 2023-03-29 01:11:43.908041984+00:00    2023-03-29 01:11:48.220000+00:00
#
#   params.maxIter params.regParam             tags.mlflow.source.git.commit  \
# 0             10           0.001  1d14407660f321086ef27b91b0e06ca91cd34b18
# 1              8            0.01  1d14407660f321086ef27b91b0e06ca91cd34b18
# 2              8            0.01  1d14407660f321086ef27b91b0e06ca91cd34b18
# 3             10           0.002  1d14407660f321086ef27b91b0e06ca91cd34b18
#
#                              tags.mlflow.source.name tags.mlflow.user  \
# 0  /usr/local/lib/python3.7/site-packages/ipykern...      pauldefusco
# 1  /usr/local/lib/python3.7/site-packages/ipykern...      pauldefusco
# 2  /usr/local/lib/python3.7/site-packages/ipykern...      pauldefusco
# 3  /usr/local/lib/python3.7/site-packages/ipykern...      pauldefusco
#
#   tags.mlflow.source.type tags.row_count tags.iceberg_parent_id  \
# 0                   LOCAL           None                   None
# 1                   LOCAL           None                   None
# 2                   LOCAL              4                   None
# 3                   LOCAL              8    5150219139107687331
#
#   tags.iceberg_snapshot_id tags.iceberg_snapshot_committed_at
# 0                     None                               None
# 1                     None                               None
# 2      5150219139107687331                         03/29/2023
# 3      8171776268264279750                         03/29/2023

# %%
#Retrieve snapshot_id from Experiments page or above dataframe. Use the Snapshot ID from the first experiment.
snapshot_id = "5150219139107687331"
exp3(training_df, snapshot_id)
# Out:
#                 run_id        experiment_id                   status  \
# 0  kfnc-iesm-r79x-nqcp  p1y7-kv7u-fkya-ca0e   EXPERIMENT_RUN_RUNNING
# 1  vaza-u8gd-dbkd-k4ow  p1y7-kv7u-fkya-ca0e    EXPERIMENT_RUN_FAILED
# 2  55oy-jgoj-sxwp-tp7b  p1y7-kv7u-fkya-ca0e  EXPERIMENT_RUN_FINISHED
# 3  bmxd-ywal-739v-3ikq  p1y7-kv7u-fkya-ca0e  EXPERIMENT_RUN_FINISHED
# 4  tndc-jcty-7qn9-jxsu  p1y7-kv7u-fkya-ca0e  EXPERIMENT_RUN_FINISHED
# 5  4yk0-cwcg-9hcn-c7k9  p1y7-kv7u-fkya-ca0e  EXPERIMENT_RUN_FINISHED
#
#                                         artifact_uri  \
# 0  /home/cdsw/.experiments/p1y7-kv7u-fkya-ca0e/kf...
# 1  /home/cdsw/.experiments/p1y7-kv7u-fkya-ca0e/va...
# 2  /home/cdsw/.experiments/p1y7-kv7u-fkya-ca0e/55...
# 3  /home/cdsw/.experiments/p1y7-kv7u-fkya-ca0e/bm...
# 4  /home/cdsw/.experiments/p1y7-kv7u-fkya-ca0e/tn...
# 5  /home/cdsw/.experiments/p1y7-kv7u-fkya-ca0e/4y...
#
#                            start_time                            end_time  \
# 0 2023-03-29 01:04:44.571115008+00:00                                 NaT
# 1 2023-03-29 01:06:53.296070144+00:00 2023-03-29 01:06:56.807000064+00:00
# 2 2023-03-29 01:09:43.688317184+00:00    2023-03-29 01:09:46.864000+00:00
# 3 2023-03-29 01:11:43.908041984+00:00    2023-03-29 01:11:48.220000+00:00
# 4 2023-03-29 01:14:32.279436032+00:00 2023-03-29 01:14:35.438000128+00:00
# 5 2023-03-29 01:15:29.313084928+00:00    2023-03-29 01:15:32.180000+00:00
#
#   params.maxIter params.regParam             tags.mlflow.source.git.commit  \
# 0             10           0.001  1d14407660f321086ef27b91b0e06ca91cd34b18
# 1              8            0.01  1d14407660f321086ef27b91b0e06ca91cd34b18
# 2              8            0.01  1d14407660f321086ef27b91b0e06ca91cd34b18
# 3             10           0.002  1d14407660f321086ef27b91b0e06ca91cd34b18
# 4              7           0.005  1d14407660f321086ef27b91b0e06ca91cd34b18
# 5              7           0.005  1d14407660f321086ef27b91b0e06ca91cd34b18
#
#                              tags.mlflow.source.name tags.mlflow.user  \
# 0  /usr/local/lib/python3.7/site-packages/ipykern...      pauldefusco
# 1  /usr/local/lib/python3.7/site-packages/ipykern...      pauldefusco
# 2  /usr/local/lib/python3.7/site-packages/ipykern...      pauldefusco
# 3  /usr/local/lib/python3.7/site-packages/ipykern...      pauldefusco
# 4  /usr/local/lib/python3.7/site-packages/ipykern...      pauldefusco
# 5  /usr/local/lib/python3.7/site-packages/ipykern...      pauldefusco
#
#   tags.mlflow.source.type tags.row_count tags.iceberg_parent_id  \
# 0                   LOCAL           None                   None
# 1                   LOCAL           None                   None
# 2                   LOCAL              4                   None
# 3                   LOCAL              8    5150219139107687331
# 4                   LOCAL              4    5150219139107687331
# 5                   LOCAL              4                   None
#
#   tags.iceberg_snapshot_id tags.iceberg_snapshot_committed_at
# 0                     None                               None
# 1                     None                               None
# 2      5150219139107687331                         03/29/2023
# 3      8171776268264279750                         03/29/2023
# 4      8171776268264279750                         03/29/2023
# 5      5150219139107687331                         03/29/2023
